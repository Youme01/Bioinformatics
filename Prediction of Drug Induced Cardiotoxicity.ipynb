# %%
! pip install chembl_webresource_client

# %% [markdown]
# # CHEMBL DATABASE

# %% [markdown]
# ## Importing Libraries

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
#import deepchem as dc

# %% [markdown]
# ### Search for target HERG

# %%
# Target search for herg blockers 
target = new_client.target
target_query = target.search('herg')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'Q12809', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# 0                                           HERG   19.0               False
# 1  Melanin-concentrating hormone receptor 2/HERG   10.0               False
# 2                Voltage-gated potassium channel    2.0               False
#
#   target_chembl_id                                  target_components  \
# 0        CHEMBL240  [{'accession': 'Q12809', 'component_descriptio...
# 1    CHEMBL4106188  [{'accession': 'Q12809', 'component_descriptio...
# 2    CHEMBL2362996  [{'accession': 'P51787', 'component_descriptio...
#
#          target_type  tax_id
# 0     SINGLE PROTEIN    9606
# 1  SELECTIVITY GROUP    9606
# ...

# %%
#Fifth entry
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL240'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None       305156                  []    CHEMBL841079
# 1                 None       305157                  []    CHEMBL841078
# 2                 None       305244                  []    CHEMBL691014
# 3                 None       305245                  []    CHEMBL691013
# 4                 None       306561                  []    CHEMBL691014
# ...                ...          ...                 ...             ...
# 11881             None     18812457                  []   CHEMBL4276288
# 11882             None     18813960                  []   CHEMBL4276588
# 11883             None     18813961                  []   CHEMBL4276588
# 11884             None     18813962                  []   CHEMBL4276588
# 11885             None     18813963                  []   CHEMBL4276588
#
#                                        assay_description assay_type  \
# ...

# %%
df.assay_chembl_id.unique()
# Out:
# array(['CHEMBL841079', 'CHEMBL841078', 'CHEMBL691014', ...,
#        'CHEMBL4275853', 'CHEMBL4276288', 'CHEMBL4276588'], dtype=object)

# %%
data = df.drop_duplicates(subset ="assay_chembl_id", 
                     keep = False, inplace = True)

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None       305156                  []    CHEMBL841079
# 1                 None       305157                  []    CHEMBL841078
# 5                 None       306562                  []    CHEMBL877203
# 10                None       313238                  []    CHEMBL749472
# 11                None       314576                  []    CHEMBL656375
# ...                ...          ...                 ...             ...
# 11874             None     18790337                  []   CHEMBL4272649
# 11875             None     18790349                  []   CHEMBL4272648
# 11876             None     18802718                  []   CHEMBL4274732
# 11880             None     18810488                  []   CHEMBL4275853
# 11881             None     18812457                  []   CHEMBL4276288
#
#                                        assay_description assay_type  \
# ...

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None       305156                  []    CHEMBL841079
# 1                 None       305157                  []    CHEMBL841078
# 5                 None       306562                  []    CHEMBL877203
# 10                None       313238                  []    CHEMBL749472
# 11                None       314576                  []    CHEMBL656375
# ...                ...          ...                 ...             ...
# 11874             None     18790337                  []   CHEMBL4272649
# 11875             None     18790349                  []   CHEMBL4272648
# 11876             None     18802718                  []   CHEMBL4274732
# 11880             None     18810488                  []   CHEMBL4275853
# 11881             None     18812457                  []   CHEMBL4276288
#
#                                        assay_description assay_type  \
# ...

# %%
# !pip install xlrd
# !pip install xlsx
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement xlsx
# ERROR: No matching distribution found for xlsx

# %%
df2 = pd.read_excel('data1.xls','hERGdata_supporting')

# %%
df2.head(3)
# Out:
#               Journal name                                      Article Title  \
# 0  Molecular Pharmaceutics  hERG Classification Model Based on a Combinati...
# 1  Molecular Pharmaceutics  hERG Classification Model Based on a Combinati...
# 2  Molecular Pharmaceutics  hERG Classification Model Based on a Combinati...
#
#     volume   issue   year   page_start   page_end   assay_name  \
# 0        5       1   2007          117        127  Patch Clamp
# 1        5       1   2007          117        127  Patch Clamp
# 2        5       1   2007          117        127  Patch Clamp
#
#    condition_name  cell_line_name  ...  \
# 0            None         Unknown  ...
# 1            None         Unknown  ...
# 2            None         Unknown  ...
#
#                                               smiles         Compound_name  \
# 0  Fc1ccc2c(o[nH0]c2C2CC[N+](CC2)CCC2C(=O)[N+]=3C...  9-HYDROXYRISPERIDONE
# 1  O=C(NCCCN(C)c1[nH0]c(C)c2cc(OC)c(OC)cc2[nH0]1)...             ALFUZOSIN
# ...

# %%
#df3 = pd.read_csv('data2M.xlsx')

# %%
df3
# Out:
#                                                      .  \
# 0                                             Compound
# 1                                                   1
# 2                                                  NaN
# 3                                                   2
# 4                                                   3
# ..                                                 ...
# 500
# 501  Zhang, X., Rueter, J.K., Chen, Y., Moorjani, M...
# 502  Zhu, B.Y., Jia, Z.J., Zhang, P., Su, T., Huang...
# 503                                                NaN
# 504                                                NaN
#
#                                             Unnamed: 1             Unnamed: 2  \
# 0                                                  NaN                    NaN
# 1    c1cc(OC)ccc1CCN(CC2)CCC2Nc(n3)n(Cc(cc4)ccc4F)c...  (Murphy et al., 2006)
# 2                                           Astemizole                    NaN
# ...
